# %% [markdown]
# # Methods in Data Science - Solution for Homework 1 - Fall 2024 - Wilmington College
#
# **Chapter 2: Exercises 8 and 10**

# %% [markdown]
# # 8. College Dataset Analysis
#
# This exercise relates to the College data set, which can be found in the file `College.csv` on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are:
#
# - **Private**: Public/private indicator
# - **Apps**: Number of applications received
# - **Accept**: Number of applicants accepted
# - **Enroll**: Number of new students enrolled
# - **Top10perc**: New students from top 10% of high school class
# - **Top25perc**: New students from top 25% of high school class
# - **F.Undergrad**: Number of full-time undergraduates
# - **P.Undergrad**: Number of part-time undergraduates
# - **Outstate**: Out-of-state tuition
# - **Room.Board**: Room and board costs
# - **Books**: Estimated book costs
# - **Personal**: Estimated personal spending
# - **PhD**: Percent of faculty with Ph.D.s
# - **Terminal**: Percent of faculty with terminal degree
# - **S.F.Ratio**: Student/faculty ratio
# - **perc.alumni**: Percent of alumni who donate
# - **Expend**: Instructional expenditure per student
# - **Grad.Rate**: Graduation rate
#
# Before reading the data into Python, it can be viewed in Excel or a text editor.
#
# ## (a) Read Data into Python
#
# Use the `pd.read_csv()` function to read the data into Python. Call the loaded data `college`. Make sure that you have the directory set to the correct location for the data.
#
# ```python
# import pandas as pd
#
# # Read the data into Python
# college = pd.read_csv('College.csv')
# ```
#
# ## (b) Examine the Data
#
# Look at the data used in the notebook by creating and running a new cell with just the code `college` in it. You should notice that the first column is just the name of each university in a column named something like `Unnamed: 0`. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands:
#
# ```python
# college2 = pd.read_csv('College.csv', index_col=0)
# college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)
# college3 = college3.set_index('College')
# ```
#
# This has used the first column in the file as an index for the data frame. This means that pandas has given each row a name corresponding to the appropriate university. Now you should see that the first data column is `Private`. Note that the names of the colleges appear on the left of the table. We also introduced a new Python object above: a dictionary, which is specified by dictionary (key, value) pairs. Keep your modified version of the data with the following:
#
# ```python
# college = college3
# ```
#
# ## (c) Numerical Summary
#
# Use the `describe()` method to produce a numerical summary of the variables in the data set.
#
#
# ## (d) Scatterplot Matrix
#
# Use the `pd.plotting.scatter_matrix()` function to produce a scatterplot matrix of the first columns `[Top10perc, Apps, Enroll]`. Recall that you can reference a list `C` of columns of a data frame `A` using `A[C]`.
#
#
# ## (e) Boxplots of Outstate vs Private
#
# Use the `boxplot()` method of `college` to produce side-by-side boxplots of `Outstate` versus `Private`.
#
#
# ## (f) Create a New Variable 'Elite'
#
# Create a new qualitative variable, called `Elite`, by binning the `Top10perc` variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
#
# ```python
# college['Elite'] = pd.cut(college['Top10perc'], [0, 0.5, 1], labels=['No', 'Yes'])
# ```
#
# Use the `value_counts()` method of `college['Elite']` to see how many elite universities there are. Finally, use the `boxplot()` method again to produce side-by-side boxplots of `Outstate` versus `Elite`.
#
#
# ## (g) Histograms
#
# Use the `plot.hist()` method of `college` to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command `plt.subplots(2, 2)` may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments, you can divide the screen up in other combinations.
#
#
# ## (h) Summary
#
# Continue exploring the data, and provide a brief summary of what you discover.

# %%
#--------------Solution----------------#
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# (a) Read the data into Python
college = pd.read_csv('Datasets//College.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# (b) Modify the DataFrame to set the university names as the index
college2 = pd.read_csv('Datasets//College.csv', index_col=0)
college3 = college.rename(columns={'Unnamed: 0': 'College'})
college3 = college3.set_index('College')
college = college3
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# (c) Numerical summary of the dataset
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# (d) Scatterplot matrix of Top10perc, Apps, Enroll
scatter_cols = ['Top10perc', 'Apps', 'Enroll']
pd.plotting.scatter_matrix(college[scatter_cols], figsize=(10, 6))
plt.show()

# %%
# (e) Side-by-side boxplots of Outstate vs Private
sns.boxplot(x='Private', y='Outstate', data=college)
plt.title('Outstate Tuition vs Private/Public Universities')
plt.show()

# %%
# (f) Create the 'Elite' variable and plot boxplots
college['Elite'] = pd.cut(college['Top10perc'], bins=[0, 50, 100], labels=['No', 'Yes'])
elite_count = college['Elite'].value_counts()
print(elite_count)

# Side-by-side boxplots of Outstate vs Elite
sns.boxplot(x='Elite', y='Outstate', data=college)
plt.title('Outstate Tuition vs Elite Universities')
plt.show()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
# (g) Histograms of some quantitative variables
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot histograms with different bin numbers
college['Apps'].plot.hist(bins=30, ax=axes[0, 0], title='Applications')
college['Enroll'].plot.hist(bins=20, ax=axes[0, 1], title='Enrollments')
college['Outstate'].plot.hist(bins=40, ax=axes[1, 0], title='Outstate Tuition')
college['Grad.Rate'].plot.hist(bins=15, ax=axes[1, 1], title='Graduation Rate')

plt.tight_layout()
plt.show()

# %%
# (h) Further exploration summary
# We exclude non-numeric columns when calculating the correlation matrix
numeric_cols = college.select_dtypes(include='number')
correlation_matrix = numeric_cols.corr()

# Plot the correlation matrix heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numeric Variables in College Dataset')
plt.show()

# %% [markdown]
# From the correlation matrix of the College dataset, several important relationships between the variables can be observed:
#
# 1. **High correlation between `Apps`, `Accept`, and `Enroll`**:
#    - As expected, there is a very strong positive correlation between the number of applications received (`Apps`) and the number of applicants accepted (`Accept`) with a correlation of **0.94**.
#    - Similarly, the number of accepted students (`Accept`) and the number of enrolled students (`Enroll`) are highly correlated at **0.91**.
#
# 2. **Top 10% and Top 25% of high school class**:
#    - `Top10perc` (students in the top 10% of their high school class) has a strong positive correlation with `Top25perc` (students in the top 25% of their high school class) at **0.89**. This indicates that schools with a higher percentage of top 10% students also tend to have a higher percentage of students from the top 25%.
#    - `Top10perc` also has a moderate positive correlation with `Grad.Rate` (graduation rate) at **0.48**, suggesting that universities with a higher proportion of top 10% students tend to have higher graduation rates.
#
# 3. **Tuition and costs**:
#    - `Outstate` (out-of-state tuition) is moderately correlated with other cost-related variables such as `Room.Board` (room and board costs) at **0.65**. This suggests that schools with higher tuition tend to have higher room and board costs.
#    - `Expend` (instructional expenditure per student) has a moderate positive correlation with `Outstate` at **0.67**, indicating that universities with higher instructional expenditures tend to charge higher out-of-state tuition.
#
# 4. **Faculty qualifications and student-faculty ratio**:
#    - There is a strong correlation between `PhD` (percentage of faculty with PhDs) and `Terminal` (percentage of faculty with terminal degrees) at **0.85**, showing that schools with highly qualified faculty in one metric tend to excel in the other.
#    - There is a notable negative correlation between `S.F.Ratio` (student-faculty ratio) and `Terminal`/`PhD` at **-0.36** and **-0.40**, respectively. This suggests that schools with better-qualified faculty tend to have lower student-faculty ratios.
#
# 5. **Alumni donations**:
#    - `perc.alumni` (percentage of alumni who donate) has a positive correlation with `Grad.Rate` at **0.49**, suggesting that universities with higher graduation rates tend to have more engaged alumni.
#    - There is also a positive relationship between `perc.alumni` and `Expend` at **0.43**, indicating that schools with higher instructional expenditures tend to have a more generous alumni base.
#
# 6. **Graduation rate**:
#    - `Grad.Rate` (graduation rate) has moderate positive correlations with several variables, notably `Top10perc` (**0.48**) and `perc.alumni` (**0.49**). This highlights that schools with more top students and more alumni support tend to have better graduation outcomes.

# %% [markdown]
# # 10. Boston Housing Data Set Exercise
#
# This exercise involves the Boston housing data set.
#
# ### (a)
# To begin, load in the `Datasets/Boston.csv` data set, which is part of the ISLP library.
#
#
# ### (b)
# How many rows are in this data set? How many columns? What do the rows and columns represent?
#
# ### (c)
# Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.
#
# ### (d)
# Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
#
# ### (e)
# Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.
#
# ### (f)
# How many of the suburbs in this data set bound the Charles river?
#
# ### (g)
# What is the median pupil-teacher ratio among the towns in this data set?
#
# ### (h)
# Which suburb of Boston has the lowest median value of owner-occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.
#
# ### (i)
# In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
#--------------Solution----------------#
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
boston_data = pd.read_csv('Datasets/Boston.csv')
.head()boston_data
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio  lstat  medv
# 0  296     15.3   4.98  24.0
# 1  242     17.8   9.14  21.6
# 2  242     17.8   4.03  34.7
# 3  222     18.7   2.94  33.4
# 4  222     18.7   5.33  36.2

# %%
boston_data?
# Out:
# Type:        DataFrame
# String form:
# Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
#            0             1   <...> 23.9
#            504  273     21.0   6.48  22.0
#            505  273     21.0   7.88  11.9
#
#            [506 rows x 14 columns]
# Length:      506
# File:        ~/.local/lib/python3.12/site-packages/pandas/core/frame.py
# Docstring:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order. If a dict contains Series
# ...

# %%
# (b) Get the shape of the dataset
num_rows, num_columns = boston_data.shape
print(f'Number of rows: {num_rows}')
print(f'Number of columns: {num_columns}')
# Out:
# Number of rows: 506
# Number of columns: 14

# %% [markdown]
# - Rows: Each row represents a suburb in Boston, providing data on various housing and socio-economic characteristics.
# - Columns: Each column represents a different attribute related to the suburb's demographic, environmental, and housing characteristics.

# %%
# (c) Make some pairwise scatterplots of the predictors
sns.pairplot(boston_data)
plt.show()

# %%
# (d) Check predictors associated with per capita crime rate (CRIM)
# Here, we'll look at correlations with the CRIM variable
correlation_with_crim = boston_data.corr()['crim'].sort_values(ascending=False)
print("Correlation with per capita crime rate (CRIM):")
print(correlation_with_crim)
# Out:
# Correlation with per capita crime rate (CRIM):
# crim          1.000000
# rad           0.625505
# tax           0.582764
# lstat         0.455621
# nox           0.420972
# Unnamed: 0    0.407407
# indus         0.406583
# age           0.352734
# ptratio       0.289946
# chas         -0.055892
# zn           -0.200469
# rm           -0.219247
# dis          -0.379670
# medv         -0.388305
# Name: crim, dtype: float64

# %% [markdown]
# ### Correlation Analysis
#
# 1. **Positive Associations:**
#    - **rad (Index of accessibility to radial highways)**: Correlation = **0.6255**
#      - A strong positive correlation indicates that as the accessibility to radial highways increases, the per capita crime rate tends to increase as well. This may suggest that suburbs with better access to highways might also be more urbanized, leading to higher crime rates.
#
#    - **tax (Full-value property tax rate)**: Correlation = **0.5828**
#      - This strong positive correlation indicates that suburbs with higher property tax rates tend to have higher crime rates. This could imply that higher taxes may be associated with neighborhoods that have lower economic status or higher demands for public services, potentially leading to higher crime.
#
#    - **lstat (Percentage of lower status of the population)**: Correlation = **0.4556**
#      - A moderate positive correlation suggests that as the percentage of lower-status individuals in a suburb increases, the crime rate also tends to rise. This might indicate socio-economic factors influencing crime rates.
#
#    - **nox (Nitric oxides concentration)**: Correlation = **0.4209**
#      - A moderate positive correlation indicates that higher pollution levels (as measured by nitric oxides concentration) are associated with higher crime rates. This could reflect the environmental and health conditions of a suburb affecting crime.
#
#    - **Unnamed: 0 (Index or identifier)**: Correlation = **0.4074**
#      - This value may not have a direct interpretation and should be disregarded in context since it likely does not represent a meaningful variable.
#
#    - **indus (Proportion of non-retail business acres)**: Correlation = **0.4066**
#      - A moderate positive correlation suggests that suburbs with more industrial areas tend to have higher crime rates, possibly reflecting socio-economic dynamics.
#
#    - **age (Proportion of owner-occupied units built prior to 1940)**: Correlation = **0.3527**
#      - This positive correlation implies that older suburbs may be associated with higher crime rates, potentially due to older infrastructure and socio-economic challenges.
#
#    - **ptratio (Pupil-teacher ratio)**: Correlation = **0.2899**
#      - A weak positive correlation indicates that higher pupil-teacher ratios, which can suggest less effective schooling environments, may be associated with higher crime rates.
#
# 2. **Negative Associations:**
#    - **dis (Weighted distances to Boston employment centers)**: Correlation = **-0.3797**
#      - A moderate negative correlation indicates that as the distance from employment centers increases, the crime rate tends to decrease. This may suggest that suburbs further from urban centers have lower crime rates.
#
#    - **medv (Median value of owner-occupied homes)**: Correlation = **-0.3883**
#      - A moderate negative correlation suggests that suburbs with higher median home values tend to have lower crime rates. This is often the case as wealthier neighborhoods may have better security and social structures.
#
#    - **rm (Average number of rooms per dwelling)**: Correlation = **-0.2192**
#      - A weak negative correlation suggests that suburbs with larger average dwelling sizes may have lower crime rates, possibly indicating higher socio-economic status.
#
#    - **zn (Proportion of residential land zoned for large lots)**: Correlation = **-0.2005**
#      - A weak negative correlation indicates that suburbs with more land zoned for larger lots tend to have lower crime rates, possibly reflecting a suburban lifestyle with lower density.
#
#    - **chas (Charles River dummy variable)**: Correlation = **-0.0559**
#      - This very weak negative correlation suggests no meaningful relationship between being near the Charles River and crime rates.

# %%
# (e) Descriptive statistics for high crime rates, tax rates, and pupil-teacher ratios
high_crime_rate = boston_data[boston_data['crim'] > boston_data['crim'].mean()]
high_tax_rate = boston_data[boston_data['tax'] > boston_data['tax'].mean()]
high_pupil_teacher_ratio = boston_data[boston_data['ptratio'] > boston_data['ptratio'].mean()]

print(f"Number of suburbs with high crime rate: {high_crime_rate.shape[0]}")
print(f"Number of suburbs with high tax rate: {high_tax_rate.shape[0]}")
print(f"Number of suburbs with high pupil-teacher ratio: {high_pupil_teacher_ratio.shape[0]}")
# Out:
# Number of suburbs with high crime rate: 128
# Number of suburbs with high tax rate: 168
# Number of suburbs with high pupil-teacher ratio: 292

# %% [markdown]
# ### Findings
#
# 1. **High Crime Rates:**
#    - **Number of suburbs with high crime rate:** 128
#    - This indicates that a significant portion of the suburbs in the dataset experiences above-average crime rates. This could suggest underlying socio-economic issues or factors that contribute to crime, such as poverty or lack of community resources.
#
# 2. **High Tax Rates:**
#    - **Number of suburbs with high tax rate:** 168
#    - A high number of suburbs with elevated tax rates may imply a focus on funding public services, such as education and infrastructure. However, high taxes can also be a burden on residents, potentially affecting housing affordability.
#
# 3. **High Pupil-Teacher Ratios:**
#    - **Number of suburbs with high pupil-teacher ratio:** 292
#    - A considerable number of suburbs have high pupil-teacher ratios, which can be indicative of overcrowded classrooms and possibly lower quality of education. High ratios may negatively impact students' learning experiences and outcomes.

# %%
# (f) Count suburbs bounding the Charles river
charles_river_count = boston_data[boston_data['chas'] == 1].shape[0]
print(f'Number of suburbs that bound the Charles river: {charles_river_count}')
# Out:
# Number of suburbs that bound the Charles river: 35

# %%
# (g) Median pupil-teacher ratio
median_pupil_teacher_ratio = boston_data['ptratio'].median()
print(f'Median pupil-teacher ratio: {median_pupil_teacher_ratio}')
# Out:
# Median pupil-teacher ratio: 19.05

# %%
# (h) Suburb with the lowest median value of owner-occupied homes
lowest_value_suburb = boston_data.loc[boston_data['medv'].idxmin()]
print("Suburb with the lowest median value of owner-occupied homes:")
print(lowest_value_suburb)
# Out:
# Suburb with the lowest median value of owner-occupied homes:
# Unnamed: 0    399.0000
# crim           38.3518
# zn              0.0000
# indus          18.1000
# chas            0.0000
# nox             0.6930
# rm              5.4530
# age           100.0000
# dis             1.4896
# rad            24.0000
# tax           666.0000
# ptratio        20.2000
# lstat          30.5900
# medv            5.0000
# Name: 398, dtype: float64

# %% [markdown]
# ### Comparison with Overall Ranges
#
# 1. **Crime Rate (`crim`)**: The value of **38.3518** indicates a very high crime rate compared to the average suburb. High crime rates are generally associated with lower property values.
#
# 2. **Residential Land (`zn`)**: A value of **0.0000** suggests no large lot zoning, which often signifies more densely populated areas and potentially lower property values.
#
# 3. **Industrial Proportion (`indus`)**: The **18.1000** indicates a high proportion of non-retail businesses, which could be less desirable for residential living and negatively affect housing prices.
#
# 4. **Charles River (`chas`)**: The value of **0.0000** indicates this suburb does not border the Charles River, which is often considered a desirable location due to scenic views and recreational opportunities.
#
# 5. **Nitric Oxides (`nox`)**: The **0.6930** level is relatively high, indicating potential air quality issues, which could also impact property values.
#
# 6. **Average Rooms (`rm`)**: The average of **5.4530** rooms is below the general trend for Boston suburbs, which typically have higher average room counts.
#
# 7. **Age of Housing (`age`)**: A value of **100.0000** indicates that all units in this suburb were built before 1940, suggesting a potentially aging housing stock, which might be less appealing to buyers.
#
# 8. **Distance to Employment Centers (`dis`)**: A value of **1.4896** shows proximity to employment, but in the context of a low housing value, it might not be attractive enough.
#
# 9. **Accessibility (`rad`)**: A value of **24.0000** indicates very poor access to highways, which can deter potential buyers looking for convenient transportation options.
#
# 10. **Tax Rate (`tax`)**: The high tax rate of **666.0000** can be a burden for homeowners and may detract from the suburb's desirability.
#
# 11. **Pupil-Teacher Ratio (`ptratio`)**: A ratio of **20.2000** suggests a lower quality of education, which could be a concern for families.
#
# 12. **Lower Status Population (`lstat`)**: The **30.5900** percentage indicates a significant portion of the population living in lower socioeconomic conditions, which is often associated with lower property values.

# %%
# (i) Suburbs averaging more than seven and eight rooms per dwelling
more_than_seven_rooms = boston_data[boston_data['rm'] > 7].shape[0]
more_than_eight_rooms = boston_data[boston_data['rm'] > 8].shape[0]
print(f'Number of suburbs averaging more than seven rooms: {more_than_seven_rooms}')
print(f'Number of suburbs averaging more than eight rooms: {more_than_eight_rooms}')

# Additional details for suburbs with more than eight rooms
suburbs_with_more_than_eight_rooms = boston_data[boston_data['rm'] > 8]
print("Suburbs averaging more than eight rooms:")
print(suburbs_with_more_than_eight_rooms)
# Out:
# Number of suburbs averaging more than seven rooms: 64
# Number of suburbs averaging more than eight rooms: 13
# Suburbs averaging more than eight rooms:
#      Unnamed: 0     crim    zn  indus  chas     nox     rm   age     dis  rad  \
# 97           98  0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2
# 163         164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5
# 204         205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4
# 224         225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8
# 225         226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8
# 226         227  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8
# 232         233  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8
# 233         234  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8
# 253         254  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7
# ...

# %% [markdown]
# ### Comments
#
# ### 1. **Socioeconomic Indicators:**
#    - The **median value of homes (medv)** in these suburbs is generally high, suggesting that these areas are more affluent. For instance, most suburbs have median home values exceeding $50,000, indicating a strong housing market.
#    - The **pupil-teacher ratios (ptratio)** are also notable. Many suburbs have relatively low pupil-teacher ratios (around 13-18), suggesting better educational resources and smaller class sizes, which often correlates with higher property values.
#
# ### 2. **Crime Rates:**
#    - The **per capita crime rates (crim)** in the suburbs averaging more than eight rooms vary. For example, some suburbs have low crime rates (e.g., index 97 with a crime rate of 0.12083), while others like index 163 show significantly higher crime rates (1.51902). This variability indicates that a higher number of rooms does not uniformly correlate with lower crime rates.
#    - This highlights the importance of considering multiple factors when assessing the desirability of an area. While many suburbs have spacious homes, the surrounding neighborhood's safety can significantly impact property values.
#
# ### 3. **Land Use and Environment:**
#    - The **zoning (zn)** information shows that some suburbs (like index 204) have a high proportion of residential land zoned for larger lots (95.0), suggesting more spacious, potentially less densely populated neighborhoods. This often contributes to a higher quality of life and can be attractive for families.
#    - The **proximity to the Charles River (chas)** is an important feature as well. Suburbs with a high ratio of land near the river (e.g., index 163) might offer scenic views and recreational opportunities, enhancing their appeal.
#
# ### 4. **Environmental Quality:**
#    - The **nitric oxides concentration (nox)** varies across these suburbs, with values ranging from around 0.445 to 0.718. Lower pollution levels are typically associated with higher property values, as they contribute to a better living environment.
#    - The **age of the housing stock (age)** suggests that some suburbs are well-established (with high age values) and may have historical significance, while others are newer developments. Older neighborhoods may attract buyers seeking character and established communities.
#
# ### 5. **Comparative Analysis:**
#    - When comparing the suburbs that average more than eight rooms to those that do not, it is evident that the former generally provide more amenities and a higher quality of life. These factors make them desirable for families and higher-income households.
#    - Suburbs averaging more than seven rooms also indicate a trend towards larger living spaces but might not command as high property values or offer the same amenities as those averaging more than eight rooms.
